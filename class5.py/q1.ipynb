# %%
import pandas as pd

# %%
df = pd.read_csv("bhatbhateni_sales.csv")

# %%
df.head()
# Out:
#   TransactionID        Date CustomerID    CustomerName  \
# 0     TXN101590  2025-05-19   CUST1100  Sujan Shrestha
# 1     TXN103282  2025-03-07   CUST1005      Milan Lama
# 2     TXN103539  2025-10-05   CUST1130       Alina Rai
# 3     TXN102479  2025-11-12   CUST1057      Neha Karki
# 4     TXN104408  2025-10-09   CUST1005      Milan Lama
#
#                      Branch ProductCategory           ProductName  Quantity  \
# 0        Pokhara - Lakeside          Bakery  Chocolate Cake Slice         2
# 1    Butwal - Traffic Chowk   Personal Care             Dove Soap         3
# 2  Bhaktapur - Suryabinayak         Apparel         Winter Jacket         4
# 3      Kathmandu - New Road       Household        Surf Excel 1kg         4
# 4    Butwal - Traffic Chowk       Beverages  Gorkha Beer (6-pack)         2
#
#    UnitPrice  TotalAmount PaymentMethod
# 0     171.29       342.58        Khalti
# 1     149.59       448.77         eSewa
# 2    2794.25     11177.00        Khalti
# 3     399.62      1598.48          Cash
# 4     281.01       562.02         eSewa

# %%
print("Columns names")
for col_name in df.columns:
    print(col_name)
# Out:
# Columns names
# TransactionID
# Date
# CustomerID
# CustomerName
# Branch
# ProductCategory
# ProductName
# Quantity
# UnitPrice
# TotalAmount
# PaymentMethod

# %%
print("Rows: ", df.shape[0], "Columns: ", df.shape[1])
# Out:
# Rows:  18812 Columns:  11

# %%
print(df.dtypes)
# Out:
# TransactionID          str
# Date                   str
# CustomerID             str
# CustomerName           str
# Branch                 str
# ProductCategory        str
# ProductName            str
# Quantity             int64
# UnitPrice          float64
# TotalAmount        float64
# PaymentMethod          str
# dtype: object

# %%
df.describe()
# Out:
#            Quantity     UnitPrice   TotalAmount
# count  18812.000000  18441.000000  18812.000000
# mean       2.506804    728.803530   1819.990565
# std        1.114328    766.346109   2241.968350
# min        1.000000     40.140000     40.610000
# 25%        2.000000    240.160000    488.397500
# 50%        3.000000    416.780000    989.000000
# 75%        3.000000    848.320000   2142.545000
# max        4.000000   3499.280000  13997.120000

# %%
missing = pd.DataFrame({
    "Missing Count": df.isnull().sum(),
    "Missing Percentage": (df.isnull().sum() / len(df)) * 100
})

missing = missing[missing["Missing Count"] > 0]

print(missing)
# Out:
#                  Missing Count  Missing Percentage
# CustomerName               568            3.019349
# ProductCategory            282            1.499043
# UnitPrice                  371            1.972145
# PaymentMethod              468            2.487774

# %%
duplicate = df.duplicated().sum()
print ("Fully duplicated rows = ", duplicate)
# Out:
# Fully duplicated rows =  724

# %%
df[df.duplicated(subset=["TransactionID"], keep=False)]
# Out:
#       TransactionID        Date CustomerID       CustomerName  \
# 0         TXN101590  2025-05-19   CUST1100     Sujan Shrestha
# 1         TXN103282  2025-03-07   CUST1005         Milan Lama
# 2         TXN103539  2025-10-05   CUST1130          Alina Rai
# 3         TXN102479  2025-11-12   CUST1057         Neha Karki
# 4         TXN104408  2025-10-09   CUST1005         Milan Lama
# ...             ...         ...        ...                ...
# 18807     TXN102758  2025-09-22   CUST1110       Sushma Karki
# 18808     TXN105279  2025-12-14   CUST1031      Sabnam Khadka
# 18809     TXN102971  2025-05-11   CUST1002  Kritika Bhattarai
# 18810     TXN101435  2025-10-06   CUST1031                NaN
# 18811     TXN105017  2025-01-07   CUST1136      Bikash Gurung
#
#                          Branch ProductCategory           ProductName  \
# 0            Pokhara - Lakeside          Bakery  Chocolate Cake Slice
# 1        Butwal - Traffic Chowk   Personal Care             Dove Soap
# 2      Bhaktapur - Suryabinayak         Apparel         Winter Jacket
# 3          Kathmandu - New Road       Household        Surf Excel 1kg
# 4        Butwal - Traffic Chowk       Beverages  Gorkha Beer (6-pack)
# ...                         ...             ...                   ...
# 18807      Kathmandu - New Road     Electronics      USB Cable Type-C
# 18808  Bhaktapur - Suryabinayak         Grocery             Sugar 1kg
# 18809    Butwal - Traffic Chowk           Dairy           DDC Milk 1L
# 18810  Bhaktapur - Suryabinayak     Electronics            Wall Clock
# 18811  Bhaktapur - Suryabinayak     Electronics   Power Bank 10000mAh
#
#        Quantity  UnitPrice  TotalAmount      PaymentMethod
# 0             2     171.29       342.58             Khalti
# 1             3     149.59       448.77              eSewa
# 2             4    2794.25     11177.00             Khalti
# 3             4     399.62      1598.48               Cash
# 4             2     281.01       562.02              eSewa
# ...         ...        ...          ...                ...
# 18807         1     429.82       429.82               Cash
# 18808         1     546.90       546.90               Cash
# 18809         3     129.40       388.20  Debit/Credit Card
# 18810         2     781.61      1563.22               Cash
# 18811         4    3280.42     13121.68               Cash
#
# [17672 rows x 11 columns]
