# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\udita\OneDrive\Desktop\prg 200\week 4
# ['bhatbhateni_sales.csv', 'question01.ipynb']

# %%
data_frame = pd.read_csv("bhatbhateni_sales.csv")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("bhatbhateni_sales.csv")
#
# File c:\Users\udita\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
import os

print("Exists:", os.path.exists("bhatbhateni_sales.csv"))
print("Size:", os.path.getsize("bhatbhateni_sales.csv"))
# Out:
# Exists: True
# Size: 0

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\udita\OneDrive\Desktop\prg 200\wk 4 vcs

# %%
with open("bhatbhateni_sales.csv", "r", encoding="utf-8", errors="ignore") as f:
    print(f.read(300))

# %%
with open("bhatbhateni_sales (1).csv", "r", encoding="utf-8", errors="ignore") as f:
    for i in range(5):
        print(repr(f.readline()))
# Out:
# ''
# ''
# ''
# ''
# ''

# %%
import pandas as pd

data_frame = pd.read_csv("bhatbhateni_sales (1).csv", sep=None, engine="python")
print(data_frame.head())
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("bhatbhateni_sales (1).csv", sep=None, engine="python")
#       4 print(df.head())
#
# File c:\Users\udita\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data_frame = pd.read_csv("bhatbhateni_sales (1).csv", sep=";")
print(data_frame.head())
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_csv("bhatbhateni_sales (1).csv", sep=";")
#       2 print(df.head())
#
# File c:\Users\udita\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...
